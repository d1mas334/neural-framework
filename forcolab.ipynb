# %%
from google.colab import files

# %%
# !apt-get install lua5.3 -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# lua5.3 is already the newest version (5.3.6-1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
import torch
if torch.cuda.is_available():
    print(f"GPU активен: {torch.cuda.get_device_name(0)}")
else:
    print("Работает только CPU")
# Out:
# GPU активен: Tesla T4

# %%
# !lua examples\mnist_example.lua
# Out:
# lua: cannot open examplesmnist_example.lua: No such file or directory

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/

# %%
import zipfile
import os

# Замените 'ваш_архив.zip' на точное имя файла, который вы загрузили
zip_path = '/content/neural-framework.zip' 
extract_path = '/content/project' # Папка, куда всё распакуется

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Распаковка завершена! Файлы в папке:", os.listdir(extract_path))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_22980/1421723966.py in <cell line: 0>()
#       6 extract_path = '/content/project' # Папка, куда всё распакуется
#       7
# ----> 8 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       9     zip_ref.extractall(extract_path)
#      10
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1350             while True:
#    1351                 try:
# -> 1352                     self.fp = io.open(file, filemode)
#    1353                 except OSError:
#    1354                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/neural-framework.zip'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !find /content/drive/MyDrive -name "neural-framework.zip"
# Out:
# /content/drive/MyDrive/Colab Notebooks/neural-framework.zip

# %%
# !unzip "/content/drive/MyDrive/Colab Notebooks/neural-framework.zip" -d /content/my_framework
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/neural-framework.zip
#    creating: /content/my_framework/neural-framework/
#    creating: /content/my_framework/neural-framework/.git/
#   inflating: /content/my_framework/neural-framework/.git/codex-synced-branch.json
#   inflating: /content/my_framework/neural-framework/.git/config
#   inflating: /content/my_framework/neural-framework/.git/description
#   inflating: /content/my_framework/neural-framework/.git/FETCH_HEAD
#   inflating: /content/my_framework/neural-framework/.git/HEAD
#    creating: /content/my_framework/neural-framework/.git/hooks/
#   inflating: /content/my_framework/neural-framework/.git/hooks/applypatch-msg.sample
#   inflating: /content/my_framework/neural-framework/.git/hooks/commit-msg.sample
#   inflating: /content/my_framework/neural-framework/.git/hooks/fsmonitor-watchman.sample
#   inflating: /content/my_framework/neural-framework/.git/hooks/post-update.sample
# ...

# %%
import os
os.chdir('/content/my_framework')

# %%
# !find /content -name "mnist_example.lua"
# Out:
# /content/my_framework/neural-framework/examples/mnist_example.lua

# %%
# Out:
# /content/my_framework/neural-framework

# %%
# !lua examples/mnist_example.lua
# Out:
# ...
# MNIST Example - Neural Network Training
# ...
#
# [1/5] Loading MNIST dataset...
#   - This may take a moment...
# Loading MNIST dataset from data/mnist
#   ✓ Train data size: 60000
#   ✓ Train labels size: 60000
#   ✓ Test data size: 10000
#   ✓ Test labels size: 10000
#   ✓ Input dimension: 784
#
# [2/5] Creating DataLoader...
#   - Batch size: 64
#   - Shuffle: true
#   ✓ DataLoader created
#
# [3/5] Normalizing data...
#   - Scaling pixel values from [0,255] to [0,1]
#   ✓ Data normalized
#
# [4/5] Creating neural network...
#   Architecture:
#     - Input layer: 784 neurons
#     - Hidden layer 1: 128 neurons (ReLU)
#     - Hidden layer 2: 64 neurons (ReLU)
#     - Output layer: 10 neurons (Softmax)
#   Total parameters: 784*128 + 128 + 128*64 + 64 + 64*10 + 10 =
#     109386 trainable parameters
#   ✓ Network created
#
# [5/5] Setting up training...
#   - Loss function: Cross Entropy Loss
#   - Optimizer: Momentum SGD
#     * Learning rate: 0.01
#     * Momentum: 0.9
#
# ...
